# %% [markdown]
# ## Metodos númericos - Clase 1
# IIP317W S 2 - Rodrigo Trigo

# %% [markdown]
# Aspectos relevantes de la clase.
#
# - Que es un numero (representacion binaria de un número)
# - Tipos de numeros conocidos (int, float, double)
#
# Enteros: (4 a 8 bytes, 1 bit de signo, resto numéro binario)

# %%
a = 15
print(bin(a), type(a))
# Out:
# 0b1111 <class 'int'>

# %% [markdown]
# $$ 0b1111 : 2^3 + 2^2 + 2^1 + 2^0  = 15 $$

# %%
b = -14
print(bin(b))
# Out:
# -0b1110

# %%
import sys
print(sys.maxsize, 2**63-1) # aunque en verdad este python puede tener numeros mas grandes...
# Out:
# 9223372036854775807 9223372036854775807

# %%
# Reflexion... es lo mismo... recordar al final

suma = 0
for i in range(1,1000000):
    suma += i
print(suma)
# Out:
# 499999500000

# %%
suma = 0
for i in range(999999,0,-1):
    suma += i
print(suma)
# Out:
# 499999500000

# %% [markdown]
# Decimales (numeros en punto flotante)
#
# Es representado por 2 numeros enteros, mantisa y exponente, cada uno tiene un bit de signo
#
# float y double es basicamente lo mismo, solo en que en double hay mas espacio para la mantisa y el exponente

# %%
c = 1/3
print(c, type(c))
# Out:
# 0.3333333333333333 <class 'float'>

# %%
print(c+c+c)
# Out:
# 1.0

# %%
d = 1/7
print(d+d+d+d+d+d+d)
# Out:
# 0.9999999999999998

# %% [markdown]
# ohhh... mas problemas

# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004

# %% [markdown]
# Lo ultimo ocurre porque 0.1 en base 2 es 0.0001100110011001100110011001100110011001100110011...
#
# Revisar como funciona en https://docs.python.org/3/tutorial/floatingpoint.html

# %% [markdown]
# Recordemos la sumatoria de arriba... ahora que sea 1/i

# %%
suma = 0
for i in range(1,1000000):
    suma += 1/i
print(suma)
# Out:
# 14.39272572286499

# %% [markdown]
# Esta aproximación es mejor, partimos con los número insignificantes para no perderlos después

# %%
suma = 0
for i in range(999999,0,-1):
    suma += 1/i
print(suma)
# Out:
# 14.392725722865773

# %% [markdown]
# Proxima clase.... como suma/multiplica el computador, compuertas and, or y not, bitwise operators...

# %%
# spoiler....
124 >> 1 #dividir por 2
# Out:
# 62

# %%
124 << 2 #multiplicar por 4
# Out:
# 496
